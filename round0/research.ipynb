# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
market_data = pd.read_csv('round0_data.csv', sep=";", header=0)
market_data.head(10)
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          NaN
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          NaN
# 5   -1        200              KELP         2025            22          NaN
# 6   -1        300              KELP         2025            31          NaN
# 7   -1        300  RAINFOREST_RESIN         9996             2       9995.0
# 8   -1        400  RAINFOREST_RESIN         9996             2       9995.0
# 9   -1        400              KELP         2025            27          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
market_data['bid_volume_1']
# Out:
# 0        1
# 1        1
# 2       24
# 3        2
# 4       20
#         ..
# 3995    27
# 3996    21
# 3997    21
# 3998    32
# 3999     2
# Name: bid_volume_1, Length: 4000, dtype: int64
